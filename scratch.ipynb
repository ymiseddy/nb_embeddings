# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.scatter([3, 6], [3, 7])
plt.text(3,2.5, "(3,3)")
plt.text(6.2,7, "(6,7)")

plt.arrow(3,3,3,0)
plt.arrow(6,3,0,4)
plt.arrow(3,3,3,4)
plt.text(4,2, "$x_2 - x_1$")
plt.text(6.5, 5, "$y_2 - y_1$")

# %%
plt.xlim([0, 10])
plt.ylim([0, 10])

plt.annotate("", xy=(3, 6), xytext=(0, 0),
            arrowprops=dict(arrowstyle="->"))
# Out:
# Text(0, 0, '')

# %%
plt.plot(5, 5)
